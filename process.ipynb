# %%
# for detection realtime number plates

# import cv2
# from ultralytics import YOLO
# import easyocr

# # load models
# detector = YOLO(r"best.pt")
# reader = easyocr.Reader(['en'])

# cap = cv2.VideoCapture(0)  # 0 = webcam

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     results = detector(frame, conf=0.25)

#     for r in results:
#         boxes = r.boxes.xyxy.cpu().numpy().astype(int)
#         for x1, y1, x2, y2 in boxes:
#             crop = frame[y1:y2, x1:x2]

#             if crop.size > 0:
#                 ocr_result = reader.readtext(crop, detail=0)

#                 if ocr_result:
#                     text = ocr_result[0].upper().replace('-', '').replace(' ', '')
#                     cv2.putText(frame, text, (x1, y1-10),
#                                 cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,0), 2)

#             cv2.rectangle(frame, (x1,y1), (x2,y2), (0,255,0), 2)

#     cv2.imshow("ALPR Realtime", frame)

#     if cv2.waitKey(200) == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()

# %%
#ckecking for gpu
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())

# %%
yolo = YOLO("best.pt")

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")  # trained on RTX 4050

model.train(
    data="data.yaml",
    imgsz=1280,
    epochs=100,
    batch=4,
    device=0,       # GPU
    workers=8,
    project="runs",
    name="lp_yolov8m"
)
